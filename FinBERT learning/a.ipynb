# %% [markdown]
# # Module Import

# %%
import pandas as pd
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %% [markdown]
# # Data Import

# %%
data = pd.read_csv("archive/all-data.csv", encoding="latin1")

data
# Out:
#        neutral  \
# 0      neutral
# 1     negative
# 2     positive
# 3     positive
# 4     positive
# ...        ...
# 4840  negative
# 4841   neutral
# 4842  negative
# 4843  negative
# 4844  negative
#
#      According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 0     Technopolis plans to develop in stages an area...
# 1     The international electronic industry company ...
# 2     With the new production plant the company woul...
# 3     According to the company 's updated strategy f...
# 4     FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...
# ...                                                 ...
# 4840  LONDON MarketWatch -- Share prices ended lower...
# 4841  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4842  Operating profit fell to EUR 35.4 mn from EUR ...
# 4843  Net sales of the Paper segment decreased to EU...
# 4844  Sales in Finland decreased by 10.5 % in Januar...
#
# [4845 rows x 2 columns]

# %% [markdown]
# # NLP process

# %%
from transformers import pipeline

# Force the pipeline to use PyTorch ("pt")
nlp = pipeline("text-classification", model="ProsusAI/finbert", framework="pt")

# Analyze your sentences
sentences = data.iloc[:, 1].tolist()
results = nlp(sentences)

for result in results[:10]:
    print(result)
# Out:
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use mps:0
# {'label': 'neutral', 'score': 0.5338396430015564}
# {'label': 'negative', 'score': 0.9720560908317566}
# {'label': 'positive', 'score': 0.9478998780250549}
# {'label': 'positive', 'score': 0.859708309173584}
# {'label': 'positive', 'score': 0.8735626339912415}
# {'label': 'positive', 'score': 0.9481975436210632}
# {'label': 'positive', 'score': 0.9570419788360596}
# {'label': 'positive', 'score': 0.9524030685424805}
# {'label': 'positive', 'score': 0.9550248384475708}
# {'label': 'positive', 'score': 0.9371811151504517}
# {'label': 'positive', 'score': 0.9351177215576172}
# {'label': 'positive', 'score': 0.8764345049858093}
# {'label': 'positive', 'score': 0.9526545405387878}
# {'label': 'positive', 'score': 0.9537839293479919}
# {'label': 'positive', 'score': 0.9587922096252441}
# {'label': 'positive', 'score': 0.9518004655838013}
# {'label': 'positive', 'score': 0.9468708038330078}
# {'label': 'positive', 'score': 0.9508934617042542}
# {'label': 'positive', 'score': 0.951758623123169}
# {'label': 'positive', 'score': 0.9466813802719116}
# {'label': 'positive', 'score': 0.8042088150978088}
# {'label': 'positive', 'score': 0.9560876488685608}
# {'label': 'positive', 'score': 0.9523158073425293}
# {'label': 'positive', 'score': 0.9558926224708557}
# {'label': 'positive', 'score': 0.9495853781700134}
# {'label': 'positive', 'score': 0.9569340348243713}
# {'label': 'positive', 'score': 0.956375241279602}
# {'label': 'positive', 'score': 0.9561133980751038}
# {'label': 'positive', 'score': 0.9568637013435364}
# {'label': 'positive', 'score': 0.8720380067825317}
# {'label': 'positive', 'score': 0.9585705399513245}
# {'label': 'positive', 'score': 0.9534754157066345}
# {'label': 'positive', 'score': 0.9567638635635376}
# {'label': 'positive', 'score': 0.9245227575302124}
# {'label': 'positive', 'score': 0.9418976306915283}
# {'label': 'positive', 'score': 0.9560032486915588}
# {'label': 'positive', 'score': 0.9444365501403809}
# {'label': 'positive', 'score': 0.9561483860015869}
# {'label': 'positive', 'score': 0.9588885307312012}
# {'label': 'positive', 'score': 0.9516132473945618}
# {'label': 'positive', 'score': 0.9530863761901855}
# {'label': 'positive', 'score': 0.7778822779655457}
# {'label': 'positive', 'score': 0.900323748588562}
# {'label': 'positive', 'score': 0.9557326436042786}
# {'label': 'positive', 'score': 0.9581224322319031}
# {'label': 'positive', 'score': 0.9503065943717957}
# {'label': 'positive', 'score': 0.885990560054779}
# {'label': 'positive', 'score': 0.9522870182991028}
# {'label': 'positive', 'score': 0.9551298022270203}
# {'label': 'positive', 'score': 0.9562219381332397}
# {'label': 'positive', 'score': 0.9479159712791443}
# {'label': 'positive', 'score': 0.9268775582313538}
# {'label': 'negative', 'score': 0.6781284213066101}
# {'label': 'positive', 'score': 0.9487479329109192}
# {'label': 'positive', 'score': 0.9504469037055969}
# {'label': 'positive', 'score': 0.9499439001083374}
# {'label': 'positive', 'score': 0.9548594951629639}
# {'label': 'neutral', 'score': 0.8370206952095032}
# {'label': 'negative', 'score': 0.9728456735610962}
# {'label': 'positive', 'score': 0.6032133102416992}
# {'label': 'neutral', 'score': 0.5969043374061584}
# {'label': 'positive', 'score': 0.8480120301246643}
# {'label': 'positive', 'score': 0.7141032814979553}
# {'label': 'neutral', 'score': 0.9087985754013062}
# {'label': 'positive', 'score': 0.890945553779602}
# {'label': 'positive', 'score': 0.9395756125450134}
# {'label': 'positive', 'score': 0.6865692734718323}
# {'label': 'positive', 'score': 0.9030376076698303}
# {'label': 'neutral', 'score': 0.8199654221534729}
# {'label': 'positive', 'score': 0.9048182368278503}
# {'label': 'neutral', 'score': 0.8050641417503357}
# {'label': 'neutral', 'score': 0.9215428233146667}
# {'label': 'positive', 'score': 0.7793616652488708}
# {'label': 'positive', 'score': 0.9369637966156006}
# {'label': 'positive', 'score': 0.9256111979484558}
# {'label': 'positive', 'score': 0.8757725954055786}
# {'label': 'positive', 'score': 0.9414548277854919}
# {'label': 'positive', 'score': 0.7350793480873108}
# {'label': 'positive', 'score': 0.7350793480873108}
# {'label': 'neutral', 'score': 0.9568549990653992}
# {'label': 'positive', 'score': 0.7253148555755615}
# {'label': 'neutral', 'score': 0.9281978011131287}
# {'label': 'positive', 'score': 0.8545543551445007}
# {'label': 'positive', 'score': 0.9398056268692017}
# {'label': 'neutral', 'score': 0.9423117637634277}
# {'label': 'positive', 'score': 0.9504197239875793}
# {'label': 'positive', 'score': 0.9518874287605286}
# {'label': 'positive', 'score': 0.9498839974403381}
# {'label': 'positive', 'score': 0.9578178524971008}
# {'label': 'positive', 'score': 0.8797695636749268}
# {'label': 'positive', 'score': 0.7422716021537781}
# {'label': 'positive', 'score': 0.945219099521637}
# {'label': 'positive', 'score': 0.9514082074165344}
# {'label': 'positive', 'score': 0.9555687308311462}
# {'label': 'positive', 'score': 0.9526955485343933}
# {'label': 'positive', 'score': 0.9544605612754822}
# {'label': 'positive', 'score': 0.9548685550689697}
# {'label': 'positive', 'score': 0.9597418308258057}
# {'label': 'positive', 'score': 0.9323959946632385}
# {'label': 'positive', 'score': 0.958209216594696}
# {'label': 'positive', 'score': 0.9540417790412903}
# {'label': 'positive', 'score': 0.9580792784690857}
# {'label': 'positive', 'score': 0.8556315898895264}
# {'label': 'positive', 'score': 0.94536954164505}
# {'label': 'positive', 'score': 0.9532979130744934}
# {'label': 'positive', 'score': 0.9535810947418213}
# {'label': 'positive', 'score': 0.9527251720428467}
# {'label': 'positive', 'score': 0.9517654180526733}
# {'label': 'positive', 'score': 0.9582593441009521}
# {'label': 'neutral', 'score': 0.9089974164962769}
# {'label': 'positive', 'score': 0.9500165581703186}
# {'label': 'positive', 'score': 0.9486861228942871}
# {'label': 'positive', 'score': 0.9563605189323425}
# {'label': 'positive', 'score': 0.9533369541168213}
# {'label': 'positive', 'score': 0.8905268311500549}
# {'label': 'positive', 'score': 0.9523863792419434}
# {'label': 'positive', 'score': 0.9582113027572632}
# {'label': 'positive', 'score': 0.9514827728271484}
# {'label': 'positive', 'score': 0.9521844387054443}
# {'label': 'positive', 'score': 0.9562891721725464}
# {'label': 'positive', 'score': 0.9552369117736816}
# {'label': 'positive', 'score': 0.953300952911377}
# {'label': 'positive', 'score': 0.9358187317848206}
# {'label': 'positive', 'score': 0.9588744044303894}
# {'label': 'positive', 'score': 0.9377506375312805}
# {'label': 'positive', 'score': 0.9480218291282654}
# {'label': 'neutral', 'score': 0.7926616072654724}
# {'label': 'positive', 'score': 0.9546906352043152}
# {'label': 'positive', 'score': 0.949867308139801}
# {'label': 'positive', 'score': 0.9456790089607239}
# {'label': 'positive', 'score': 0.9590121507644653}
# {'label': 'positive', 'score': 0.9498023986816406}
# {'label': 'positive', 'score': 0.943608283996582}
# {'label': 'positive', 'score': 0.9595321416854858}
# {'label': 'positive', 'score': 0.6898267269134521}
# {'label': 'positive', 'score': 0.9478530883789062}
# {'label': 'positive', 'score': 0.8287461400032043}
# {'label': 'positive', 'score': 0.9465399384498596}
# {'label': 'neutral', 'score': 0.5803664326667786}
# {'label': 'positive', 'score': 0.9478166699409485}
# {'label': 'positive', 'score': 0.9437436461448669}
# {'label': 'positive', 'score': 0.949806809425354}
# {'label': 'positive', 'score': 0.9539974927902222}
# {'label': 'positive', 'score': 0.9478088617324829}
# {'label': 'positive', 'score': 0.9540956020355225}
# {'label': 'positive', 'score': 0.9348458051681519}
# {'label': 'positive', 'score': 0.9510299563407898}
# {'label': 'positive', 'score': 0.9220630526542664}
# {'label': 'positive', 'score': 0.779224157333374}
# {'label': 'positive', 'score': 0.6922134160995483}
# {'label': 'positive', 'score': 0.9492648839950562}
# {'label': 'positive', 'score': 0.9574837684631348}
# {'label': 'positive', 'score': 0.682267963886261}
# {'label': 'positive', 'score': 0.9068472385406494}
# {'label': 'positive', 'score': 0.9564671516418457}
# {'label': 'positive', 'score': 0.9521587491035461}
# {'label': 'positive', 'score': 0.9569885730743408}
# {'label': 'positive', 'score': 0.9566065073013306}
# {'label': 'neutral', 'score': 0.9248035550117493}
# {'label': 'positive', 'score': 0.9298374056816101}
# {'label': 'positive', 'score': 0.9577293992042542}
# {'label': 'positive', 'score': 0.9577295780181885}
# {'label': 'positive', 'score': 0.9576215744018555}
# {'label': 'positive', 'score': 0.9573447704315186}
# {'label': 'positive', 'score': 0.959672749042511}
# {'label': 'positive', 'score': 0.9584378004074097}
# {'label': 'positive', 'score': 0.9584648609161377}
# {'label': 'positive', 'score': 0.9580706357955933}
# {'label': 'positive', 'score': 0.9581965208053589}
# {'label': 'positive', 'score': 0.9585912227630615}
# {'label': 'positive', 'score': 0.958268404006958}
# {'label': 'positive', 'score': 0.9585778713226318}
# {'label': 'positive', 'score': 0.957273542881012}
# {'label': 'positive', 'score': 0.9579417705535889}
# {'label': 'positive', 'score': 0.9572929739952087}
# {'label': 'positive', 'score': 0.9591825008392334}
# {'label': 'positive', 'score': 0.9573051929473877}
# {'label': 'positive', 'score': 0.9540627002716064}
# {'label': 'positive', 'score': 0.9580204486846924}
# {'label': 'positive', 'score': 0.954177737236023}
# {'label': 'positive', 'score': 0.9586362838745117}
# {'label': 'positive', 'score': 0.9543623328208923}
# {'label': 'positive', 'score': 0.954304575920105}
# {'label': 'positive', 'score': 0.9523400068283081}
# {'label': 'positive', 'score': 0.9562000036239624}
# {'label': 'neutral', 'score': 0.889592170715332}
# {'label': 'positive', 'score': 0.9578287601470947}
# {'label': 'positive', 'score': 0.9540409445762634}
# {'label': 'positive', 'score': 0.957751452922821}
# {'label': 'positive', 'score': 0.9479404091835022}
# {'label': 'positive', 'score': 0.9422019720077515}
# {'label': 'positive', 'score': 0.949716329574585}
# {'label': 'positive', 'score': 0.9525766372680664}
# {'label': 'positive', 'score': 0.9513660073280334}
# {'label': 'positive', 'score': 0.9490973949432373}
# {'label': 'positive', 'score': 0.9534717202186584}
# {'label': 'positive', 'score': 0.9518585801124573}
# {'label': 'positive', 'score': 0.9485191106796265}
# {'label': 'positive', 'score': 0.952360987663269}
# {'label': 'positive', 'score': 0.9541842937469482}
# {'label': 'positive', 'score': 0.952100396156311}
# {'label': 'positive', 'score': 0.952399730682373}
# {'label': 'positive', 'score': 0.9289036989212036}
# {'label': 'positive', 'score': 0.9487900733947754}
# {'label': 'positive', 'score': 0.9557422399520874}
# {'label': 'positive', 'score': 0.947320282459259}
# {'label': 'positive', 'score': 0.9575730562210083}
# {'label': 'positive', 'score': 0.9484376907348633}
# {'label': 'positive', 'score': 0.952388346195221}
# {'label': 'neutral', 'score': 0.915149986743927}
# {'label': 'positive', 'score': 0.9401109218597412}
# {'label': 'positive', 'score': 0.9523764252662659}
# {'label': 'positive', 'score': 0.9477782249450684}
# {'label': 'positive', 'score': 0.9509323835372925}
# {'label': 'positive', 'score': 0.9582543969154358}
# {'label': 'positive', 'score': 0.9568543434143066}
# {'label': 'positive', 'score': 0.9493649005889893}
# {'label': 'positive', 'score': 0.9486252665519714}
# {'label': 'positive', 'score': 0.9567172527313232}
# {'label': 'positive', 'score': 0.9567611217498779}
# {'label': 'positive', 'score': 0.7711489200592041}
# {'label': 'positive', 'score': 0.9493117928504944}
# {'label': 'positive', 'score': 0.8008946180343628}
# {'label': 'positive', 'score': 0.9562361240386963}
# {'label': 'positive', 'score': 0.9539071321487427}
# {'label': 'positive', 'score': 0.9578080177307129}
# {'label': 'positive', 'score': 0.9502207636833191}
# {'label': 'positive', 'score': 0.9484496116638184}
# {'label': 'positive', 'score': 0.949411928653717}
# {'label': 'positive', 'score': 0.9506598114967346}
# {'label': 'positive', 'score': 0.9497696757316589}
# {'label': 'positive', 'score': 0.9510608911514282}
# {'label': 'neutral', 'score': 0.9395135045051575}
# {'label': 'positive', 'score': 0.9403829574584961}
# {'label': 'positive', 'score': 0.9520435333251953}
# {'label': 'positive', 'score': 0.9561225175857544}
# {'label': 'positive', 'score': 0.9556911587715149}
# {'label': 'positive', 'score': 0.9527337551116943}
# {'label': 'positive', 'score': 0.9581008553504944}
# {'label': 'positive', 'score': 0.9520371556282043}
# {'label': 'positive', 'score': 0.950566291809082}
# {'label': 'positive', 'score': 0.9571793675422668}
# {'label': 'positive', 'score': 0.9530327916145325}
# {'label': 'positive', 'score': 0.9512874484062195}
# {'label': 'positive', 'score': 0.9514315128326416}
# {'label': 'positive', 'score': 0.9511398077011108}
# {'label': 'positive', 'score': 0.9508541226387024}
# {'label': 'positive', 'score': 0.9522541761398315}
# {'label': 'positive', 'score': 0.951726496219635}
# {'label': 'positive', 'score': 0.953498363494873}
# {'label': 'positive', 'score': 0.9536495208740234}
# {'label': 'positive', 'score': 0.9513079524040222}
# {'label': 'positive', 'score': 0.952256977558136}
# {'label': 'positive', 'score': 0.952981173992157}
# {'label': 'positive', 'score': 0.9541443586349487}
# {'label': 'positive', 'score': 0.955996036529541}
# {'label': 'positive', 'score': 0.9562947750091553}
# {'label': 'positive', 'score': 0.9558320045471191}
# {'label': 'positive', 'score': 0.9570191502571106}
# {'label': 'positive', 'score': 0.9581961631774902}
# {'label': 'positive', 'score': 0.9583193063735962}
# {'label': 'positive', 'score': 0.9549556970596313}
# {'label': 'positive', 'score': 0.9541937112808228}
# {'label': 'positive', 'score': 0.9409580230712891}
# {'label': 'positive', 'score': 0.9519789218902588}
# {'label': 'positive', 'score': 0.9532347917556763}
# {'label': 'positive', 'score': 0.9524388313293457}
# {'label': 'positive', 'score': 0.9545613527297974}
# {'label': 'positive', 'score': 0.9176576733589172}
# {'label': 'positive', 'score': 0.9048781991004944}
# {'label': 'positive', 'score': 0.9546872973442078}
# {'label': 'positive', 'score': 0.9558489918708801}
# {'label': 'positive', 'score': 0.9554272294044495}
# {'label': 'positive', 'score': 0.9569000601768494}
# {'label': 'positive', 'score': 0.9556383490562439}
# {'label': 'positive', 'score': 0.9477670192718506}
# {'label': 'positive', 'score': 0.9379513263702393}
# {'label': 'positive', 'score': 0.9538990259170532}
# {'label': 'positive', 'score': 0.9138257503509521}
# {'label': 'positive', 'score': 0.9511131644248962}
# {'label': 'positive', 'score': 0.9527983069419861}
# {'label': 'positive', 'score': 0.9575633406639099}
# {'label': 'positive', 'score': 0.9518836736679077}
# {'label': 'positive', 'score': 0.9508129358291626}
# {'label': 'positive', 'score': 0.8788765072822571}
# {'label': 'positive', 'score': 0.930995762348175}
# {'label': 'positive', 'score': 0.9524670839309692}
# {'label': 'positive', 'score': 0.9542987942695618}
# {'label': 'positive', 'score': 0.9564173221588135}
# {'label': 'positive', 'score': 0.7971523404121399}
# {'label': 'positive', 'score': 0.9544079303741455}
# {'label': 'positive', 'score': 0.9502228498458862}
# {'label': 'positive', 'score': 0.9531696438789368}
# {'label': 'positive', 'score': 0.9441308975219727}
# {'label': 'neutral', 'score': 0.8744381070137024}
# {'label': 'positive', 'score': 0.9363015294075012}
# {'label': 'positive', 'score': 0.9572573304176331}
# {'label': 'neutral', 'score': 0.9291146397590637}
# {'label': 'positive', 'score': 0.9531303644180298}
# {'label': 'positive', 'score': 0.9467967748641968}
# {'label': 'positive', 'score': 0.9471308588981628}
# {'label': 'positive', 'score': 0.820917010307312}
# {'label': 'positive', 'score': 0.9538818597793579}
# {'label': 'positive', 'score': 0.9575892090797424}
# {'label': 'positive', 'score': 0.8931047916412354}
# {'label': 'positive', 'score': 0.7511500716209412}
# {'label': 'positive', 'score': 0.9574987292289734}
# {'label': 'positive', 'score': 0.9496396780014038}
# {'label': 'neutral', 'score': 0.8594914078712463}
# {'label': 'positive', 'score': 0.9489269256591797}
# {'label': 'positive', 'score': 0.9234378337860107}
# {'label': 'positive', 'score': 0.9293314814567566}
# {'label': 'positive', 'score': 0.9140536189079285}
# {'label': 'neutral', 'score': 0.49933499097824097}
# {'label': 'positive', 'score': 0.9576294422149658}
# {'label': 'positive', 'score': 0.9505127668380737}
# {'label': 'positive', 'score': 0.9491443634033203}
# {'label': 'positive', 'score': 0.9425209760665894}
# {'label': 'positive', 'score': 0.7344662547111511}
# {'label': 'positive', 'score': 0.9395426511764526}
# {'label': 'positive', 'score': 0.9527636766433716}
# {'label': 'positive', 'score': 0.9517326951026917}
# {'label': 'positive', 'score': 0.9529046416282654}
# {'label': 'positive', 'score': 0.9287468791007996}
# {'label': 'positive', 'score': 0.9564048647880554}
# {'label': 'positive', 'score': 0.9541828632354736}
# {'label': 'positive', 'score': 0.9097484946250916}
# {'label': 'positive', 'score': 0.9525002837181091}
# {'label': 'positive', 'score': 0.952499508857727}
# {'label': 'positive', 'score': 0.9526435732841492}
# {'label': 'positive', 'score': 0.9513264298439026}
# {'label': 'positive', 'score': 0.9487338662147522}
# {'label': 'positive', 'score': 0.9541347026824951}
# {'label': 'positive', 'score': 0.9538794755935669}
# {'label': 'positive', 'score': 0.9357637166976929}
# {'label': 'positive', 'score': 0.9316152930259705}
# {'label': 'positive', 'score': 0.9541093707084656}
# {'label': 'positive', 'score': 0.9489383101463318}
# {'label': 'positive', 'score': 0.9473865628242493}
# {'label': 'positive', 'score': 0.9492195248603821}
# {'label': 'positive', 'score': 0.9573681354522705}
# {'label': 'positive', 'score': 0.955447256565094}
# {'label': 'positive', 'score': 0.9495242238044739}
# {'label': 'positive', 'score': 0.9482986330986023}
# {'label': 'positive', 'score': 0.8124300241470337}
# {'label': 'positive', 'score': 0.952095627784729}
# {'label': 'positive', 'score': 0.9565694332122803}
# {'label': 'positive', 'score': 0.9592373967170715}
# {'label': 'positive', 'score': 0.9522169828414917}
# {'label': 'positive', 'score': 0.9448325634002686}
# {'label': 'positive', 'score': 0.9456830024719238}
# {'label': 'positive', 'score': 0.9520832300186157}
# {'label': 'positive', 'score': 0.9529233574867249}
# {'label': 'positive', 'score': 0.9335911870002747}
# {'label': 'positive', 'score': 0.9504677653312683}
# {'label': 'positive', 'score': 0.9612429738044739}
# {'label': 'positive', 'score': 0.953841507434845}
# {'label': 'positive', 'score': 0.9554136991500854}
# {'label': 'positive', 'score': 0.9102773070335388}
# {'label': 'positive', 'score': 0.9552606344223022}
# {'label': 'positive', 'score': 0.9536634683609009}
# {'label': 'positive', 'score': 0.9538676738739014}
# {'label': 'positive', 'score': 0.9518146514892578}
# {'label': 'positive', 'score': 0.9528653025627136}
# {'label': 'positive', 'score': 0.9548312425613403}
# {'label': 'positive', 'score': 0.8663446307182312}
# {'label': 'positive', 'score': 0.9584312438964844}
# {'label': 'positive', 'score': 0.9569180607795715}
# {'label': 'positive', 'score': 0.9564406275749207}
# {'label': 'positive', 'score': 0.9545786380767822}
# {'label': 'positive', 'score': 0.8539078235626221}
# {'label': 'positive', 'score': 0.9333594441413879}
# {'label': 'positive', 'score': 0.9521722197532654}
# {'label': 'positive', 'score': 0.9546371102333069}
# {'label': 'positive', 'score': 0.9524592757225037}
# {'label': 'positive', 'score': 0.9466545581817627}
# {'label': 'positive', 'score': 0.9546620845794678}
# {'label': 'positive', 'score': 0.9557426571846008}
# {'label': 'positive', 'score': 0.9435412287712097}
# {'label': 'positive', 'score': 0.9576616883277893}
# {'label': 'positive', 'score': 0.9416772723197937}
# {'label': 'positive', 'score': 0.9285363554954529}
# {'label': 'positive', 'score': 0.9507561326026917}
# {'label': 'positive', 'score': 0.951855480670929}
# {'label': 'positive', 'score': 0.9495307803153992}
# {'label': 'positive', 'score': 0.9493355751037598}
# {'label': 'positive', 'score': 0.950324535369873}
# {'label': 'positive', 'score': 0.9509617686271667}
# {'label': 'positive', 'score': 0.8297045826911926}
# {'label': 'positive', 'score': 0.8891890645027161}
# {'label': 'positive', 'score': 0.9294924736022949}
# {'label': 'positive', 'score': 0.870715320110321}
# {'label': 'neutral', 'score': 0.7234473824501038}
# {'label': 'positive', 'score': 0.8683156371116638}
# {'label': 'neutral', 'score': 0.5976340174674988}
# {'label': 'neutral', 'score': 0.6056218147277832}
# {'label': 'positive', 'score': 0.7192298769950867}
# {'label': 'positive', 'score': 0.9488765597343445}
# {'label': 'positive', 'score': 0.9418906569480896}
# {'label': 'positive', 'score': 0.8766722679138184}
# {'label': 'positive', 'score': 0.8879904747009277}
# {'label': 'positive', 'score': 0.9056777358055115}
# {'label': 'positive', 'score': 0.8664877414703369}
# {'label': 'positive', 'score': 0.8793733716011047}
# {'label': 'neutral', 'score': 0.9413021206855774}
# {'label': 'neutral', 'score': 0.8445179462432861}
# {'label': 'positive', 'score': 0.5070740580558777}
# {'label': 'positive', 'score': 0.9363936185836792}
# {'label': 'positive', 'score': 0.8914108276367188}
# {'label': 'neutral', 'score': 0.9308101534843445}
# {'label': 'neutral', 'score': 0.9352939128875732}
# {'label': 'positive', 'score': 0.9134439826011658}
# {'label': 'neutral', 'score': 0.9524661898612976}
# {'label': 'neutral', 'score': 0.9490532875061035}
# {'label': 'neutral', 'score': 0.8934164047241211}
# {'label': 'neutral', 'score': 0.8952959775924683}
# {'label': 'neutral', 'score': 0.9112374782562256}
# {'label': 'neutral', 'score': 0.8876837491989136}
# {'label': 'positive', 'score': 0.8871014714241028}
# {'label': 'neutral', 'score': 0.861133337020874}
# {'label': 'negative', 'score': 0.7420691847801208}
# {'label': 'negative', 'score': 0.7268530130386353}
# {'label': 'negative', 'score': 0.7467505931854248}
# {'label': 'positive', 'score': 0.6792356371879578}
# {'label': 'positive', 'score': 0.9247874021530151}
# {'label': 'positive', 'score': 0.7679468989372253}
# {'label': 'neutral', 'score': 0.9208282232284546}
# {'label': 'positive', 'score': 0.9359976053237915}
# {'label': 'positive', 'score': 0.8822629451751709}
# {'label': 'neutral', 'score': 0.9426836371421814}
# {'label': 'neutral', 'score': 0.9432150721549988}
# {'label': 'neutral', 'score': 0.8887250423431396}
# {'label': 'positive', 'score': 0.7033101916313171}
# {'label': 'neutral', 'score': 0.9097197651863098}
# {'label': 'positive', 'score': 0.9306081533432007}
# {'label': 'neutral', 'score': 0.9333366751670837}
# {'label': 'neutral', 'score': 0.9205191135406494}
# {'label': 'positive', 'score': 0.8830614686012268}
# {'label': 'positive', 'score': 0.9495620727539062}
# {'label': 'neutral', 'score': 0.8889630436897278}
# {'label': 'positive', 'score': 0.9331527352333069}
# {'label': 'positive', 'score': 0.8688974380493164}
# {'label': 'neutral', 'score': 0.9540613293647766}
# {'label': 'neutral', 'score': 0.8796067237854004}
# {'label': 'neutral', 'score': 0.9321537017822266}
# {'label': 'positive', 'score': 0.930830717086792}
# {'label': 'neutral', 'score': 0.8563864827156067}
# {'label': 'neutral', 'score': 0.5915429592132568}
# {'label': 'neutral', 'score': 0.6818579435348511}
# {'label': 'positive', 'score': 0.902469277381897}
# {'label': 'positive', 'score': 0.9316309094429016}
# {'label': 'neutral', 'score': 0.5435435175895691}
# {'label': 'neutral', 'score': 0.9478387236595154}
# {'label': 'neutral', 'score': 0.9222538471221924}
# {'label': 'positive', 'score': 0.9022722244262695}
# {'label': 'neutral', 'score': 0.7698552012443542}
# {'label': 'positive', 'score': 0.9436876773834229}
# {'label': 'positive', 'score': 0.9458561539649963}
# {'label': 'positive', 'score': 0.7533973455429077}
# {'label': 'neutral', 'score': 0.7759832143783569}
# {'label': 'positive', 'score': 0.8060259819030762}
# {'label': 'positive', 'score': 0.9068564176559448}
# {'label': 'positive', 'score': 0.9463496804237366}
# {'label': 'neutral', 'score': 0.9463230967521667}
# {'label': 'positive', 'score': 0.6450133919715881}
# {'label': 'positive', 'score': 0.8335307240486145}
# {'label': 'positive', 'score': 0.7354922890663147}
# {'label': 'neutral', 'score': 0.9365571141242981}
# {'label': 'positive', 'score': 0.9369127750396729}
# {'label': 'neutral', 'score': 0.6065951585769653}
# {'label': 'neutral', 'score': 0.6630761623382568}
# {'label': 'positive', 'score': 0.877124547958374}
# {'label': 'positive', 'score': 0.682719349861145}
# {'label': 'neutral', 'score': 0.8965829014778137}
# {'label': 'neutral', 'score': 0.8707115054130554}
# {'label': 'neutral', 'score': 0.8746275305747986}
# {'label': 'positive', 'score': 0.9524292349815369}
# {'label': 'neutral', 'score': 0.6838153004646301}
# {'label': 'neutral', 'score': 0.8152544498443604}
# {'label': 'neutral', 'score': 0.9221022129058838}
# {'label': 'negative', 'score': 0.7376196980476379}
# {'label': 'neutral', 'score': 0.8358680605888367}
# {'label': 'neutral', 'score': 0.811684250831604}
# {'label': 'negative', 'score': 0.5494092702865601}
# {'label': 'positive', 'score': 0.8946791291236877}
# {'label': 'positive', 'score': 0.9539890289306641}
# {'label': 'positive', 'score': 0.9364407062530518}
# {'label': 'neutral', 'score': 0.8266849517822266}
# {'label': 'positive', 'score': 0.919520914554596}
# {'label': 'neutral', 'score': 0.8664608597755432}
# {'label': 'positive', 'score': 0.5009019374847412}
# {'label': 'positive', 'score': 0.9469501376152039}
# {'label': 'neutral', 'score': 0.9047197103500366}
# {'label': 'neutral', 'score': 0.6992499232292175}
# {'label': 'positive', 'score': 0.6415141224861145}
# {'label': 'positive', 'score': 0.7718547582626343}
# {'label': 'positive', 'score': 0.9412429928779602}
# {'label': 'positive', 'score': 0.9066934585571289}
# {'label': 'neutral', 'score': 0.947471559047699}
# {'label': 'negative', 'score': 0.8749944567680359}
# {'label': 'neutral', 'score': 0.9331250190734863}
# {'label': 'neutral', 'score': 0.8991951942443848}
# {'label': 'positive', 'score': 0.9276017546653748}
# {'label': 'neutral', 'score': 0.7171027660369873}
# {'label': 'positive', 'score': 0.89996337890625}
# {'label': 'positive', 'score': 0.8551781177520752}
# {'label': 'negative', 'score': 0.9408617615699768}
# {'label': 'neutral', 'score': 0.9334279894828796}
# {'label': 'neutral', 'score': 0.9404147863388062}
# {'label': 'positive', 'score': 0.7142816781997681}
# {'label': 'positive', 'score': 0.9000208377838135}
# {'label': 'neutral', 'score': 0.9388769268989563}
# {'label': 'neutral', 'score': 0.9156351685523987}
# {'label': 'neutral', 'score': 0.8418813943862915}
# {'label': 'neutral', 'score': 0.845440685749054}
# {'label': 'neutral', 'score': 0.9267677068710327}
# {'label': 'neutral', 'score': 0.7612659931182861}
# {'label': 'positive', 'score': 0.9385881423950195}
# {'label': 'positive', 'score': 0.8529085516929626}
# {'label': 'positive', 'score': 0.9555516242980957}
# {'label': 'neutral', 'score': 0.9180563688278198}
# {'label': 'neutral', 'score': 0.7047869563102722}
# {'label': 'neutral', 'score': 0.8293393850326538}
# {'label': 'neutral', 'score': 0.893537700176239}
# {'label': 'neutral', 'score': 0.58990877866745}
# {'label': 'positive', 'score': 0.9491884708404541}
# {'label': 'positive', 'score': 0.9474295973777771}
# {'label': 'positive', 'score': 0.8738863468170166}
# {'label': 'neutral', 'score': 0.9272414445877075}
# {'label': 'neutral', 'score': 0.93380206823349}
# {'label': 'negative', 'score': 0.8085235357284546}
# {'label': 'positive', 'score': 0.9381985664367676}
# {'label': 'neutral', 'score': 0.7234489917755127}
# {'label': 'positive', 'score': 0.8363695740699768}
# {'label': 'positive', 'score': 0.9327023029327393}
# {'label': 'positive', 'score': 0.7663666605949402}
# {'label': 'neutral', 'score': 0.9459455013275146}
# {'label': 'positive', 'score': 0.9543589353561401}
# {'label': 'negative', 'score': 0.9684696197509766}
# {'label': 'neutral', 'score': 0.9050558805465698}
# {'label': 'positive', 'score': 0.9557151198387146}
# {'label': 'negative', 'score': 0.9749909043312073}
# {'label': 'negative', 'score': 0.975307285785675}
# {'label': 'negative', 'score': 0.9610522389411926}
# {'label': 'positive', 'score': 0.9268353581428528}
# {'label': 'positive', 'score': 0.931209921836853}
# {'label': 'positive', 'score': 0.9350144863128662}
# {'label': 'positive', 'score': 0.9535890817642212}
# {'label': 'positive', 'score': 0.9543936848640442}
# {'label': 'positive', 'score': 0.9541172981262207}
# {'label': 'positive', 'score': 0.9277118444442749}
# {'label': 'positive', 'score': 0.9128245115280151}
# {'label': 'positive', 'score': 0.8607600927352905}
# {'label': 'positive', 'score': 0.9299185872077942}
# {'label': 'positive', 'score': 0.9498990774154663}
# {'label': 'positive', 'score': 0.9295349717140198}
# {'label': 'positive', 'score': 0.9530561566352844}
# {'label': 'positive', 'score': 0.8948312401771545}
# {'label': 'positive', 'score': 0.9538570642471313}
# {'label': 'positive', 'score': 0.9291064739227295}
# {'label': 'positive', 'score': 0.9565441608428955}
# {'label': 'positive', 'score': 0.9365189075469971}
# {'label': 'positive', 'score': 0.9339861869812012}
# {'label': 'positive', 'score': 0.9547514915466309}
# {'label': 'positive', 'score': 0.9538790583610535}
# {'label': 'positive', 'score': 0.9541807770729065}
# {'label': 'neutral', 'score': 0.6302449107170105}
# {'label': 'positive', 'score': 0.8932123184204102}
# {'label': 'neutral', 'score': 0.782505989074707}
# {'label': 'neutral', 'score': 0.8919469714164734}
# {'label': 'neutral', 'score': 0.8520930409431458}
# {'label': 'neutral', 'score': 0.8450834155082703}
# {'label': 'neutral', 'score': 0.7879351377487183}
# {'label': 'neutral', 'score': 0.945173442363739}
# {'label': 'positive', 'score': 0.623013973236084}
# {'label': 'positive', 'score': 0.6742887496948242}
# {'label': 'positive', 'score': 0.9247344136238098}
# {'label': 'neutral', 'score': 0.9552921652793884}
# {'label': 'neutral', 'score': 0.746340811252594}
# {'label': 'positive', 'score': 0.9595141410827637}
# {'label': 'positive', 'score': 0.7349608540534973}
# {'label': 'neutral', 'score': 0.8011459112167358}
# {'label': 'positive', 'score': 0.9546141624450684}
# {'label': 'positive', 'score': 0.8834011554718018}
# {'label': 'positive', 'score': 0.9110733866691589}
# {'label': 'positive', 'score': 0.9542409181594849}
# {'label': 'positive', 'score': 0.9264326095581055}
# {'label': 'positive', 'score': 0.9502047300338745}
# {'label': 'positive', 'score': 0.9331029057502747}
# {'label': 'positive', 'score': 0.9532470107078552}
# {'label': 'positive', 'score': 0.944252610206604}
# {'label': 'positive', 'score': 0.9468536376953125}
# {'label': 'positive', 'score': 0.6333298087120056}
# {'label': 'positive', 'score': 0.9504223465919495}
# {'label': 'positive', 'score': 0.9530608654022217}
# {'label': 'positive', 'score': 0.925643265247345}
# {'label': 'positive', 'score': 0.9010883569717407}
# {'label': 'positive', 'score': 0.9492983818054199}
# {'label': 'positive', 'score': 0.9289618134498596}
# {'label': 'positive', 'score': 0.9526712894439697}
# {'label': 'positive', 'score': 0.9263406991958618}
# {'label': 'positive', 'score': 0.947187066078186}
# {'label': 'positive', 'score': 0.9503867626190186}
# {'label': 'positive', 'score': 0.762416422367096}
# {'label': 'positive', 'score': 0.9500885009765625}
# {'label': 'positive', 'score': 0.9459381699562073}
# {'label': 'positive', 'score': 0.9384182691574097}
# {'label': 'positive', 'score': 0.9474212527275085}
# {'label': 'positive', 'score': 0.9456453323364258}
# {'label': 'positive', 'score': 0.9510043859481812}
# {'label': 'positive', 'score': 0.949195921421051}
# {'label': 'positive', 'score': 0.8185437321662903}
# {'label': 'positive', 'score': 0.5727666616439819}
# {'label': 'positive', 'score': 0.9527856707572937}
# {'label': 'positive', 'score': 0.8077061772346497}
# {'label': 'neutral', 'score': 0.8158502578735352}
# {'label': 'positive', 'score': 0.9415300488471985}
# {'label': 'positive', 'score': 0.7045097947120667}
# {'label': 'neutral', 'score': 0.9265217185020447}
# {'label': 'positive', 'score': 0.9305965900421143}
# {'label': 'positive', 'score': 0.5197337865829468}
# {'label': 'neutral', 'score': 0.7437869310379028}
# {'label': 'neutral', 'score': 0.8582449555397034}
# {'label': 'positive', 'score': 0.900412380695343}
# {'label': 'positive', 'score': 0.6973536610603333}
# {'label': 'positive', 'score': 0.9413097500801086}
# {'label': 'positive', 'score': 0.9262161254882812}
# {'label': 'neutral', 'score': 0.8932715654373169}
# {'label': 'positive', 'score': 0.9189315438270569}
# {'label': 'positive', 'score': 0.9546548128128052}
# {'label': 'positive', 'score': 0.9271869659423828}
# {'label': 'positive', 'score': 0.9422551989555359}
# {'label': 'positive', 'score': 0.6910361051559448}
# {'label': 'neutral', 'score': 0.7770935893058777}
# {'label': 'neutral', 'score': 0.8062708973884583}
# {'label': 'positive', 'score': 0.8537110090255737}
# {'label': 'neutral', 'score': 0.9112600684165955}
# {'label': 'positive', 'score': 0.887837290763855}
# {'label': 'positive', 'score': 0.9243733882904053}
# {'label': 'positive', 'score': 0.9259690046310425}
# {'label': 'positive', 'score': 0.9378015995025635}
# {'label': 'positive', 'score': 0.9396016001701355}
# {'label': 'positive', 'score': 0.9253900647163391}
# {'label': 'positive', 'score': 0.9409767389297485}
# {'label': 'positive', 'score': 0.9357779026031494}
# {'label': 'positive', 'score': 0.9017927646636963}
# {'label': 'positive', 'score': 0.9371623992919922}
# {'label': 'positive', 'score': 0.9350645542144775}
# {'label': 'positive', 'score': 0.9397594928741455}
# {'label': 'positive', 'score': 0.9348984360694885}
# {'label': 'positive', 'score': 0.95257967710495}
# {'label': 'positive', 'score': 0.9392776489257812}
# {'label': 'positive', 'score': 0.9334557056427002}
# {'label': 'positive', 'score': 0.8971388339996338}
# {'label': 'positive', 'score': 0.940057098865509}
# {'label': 'positive', 'score': 0.9393066763877869}
# {'label': 'positive', 'score': 0.9292150735855103}
# {'label': 'positive', 'score': 0.9394285082817078}
# {'label': 'positive', 'score': 0.9323899745941162}
# {'label': 'negative', 'score': 0.967842698097229}
# {'label': 'negative', 'score': 0.9328732490539551}
# {'label': 'positive', 'score': 0.830030083656311}
# {'label': 'positive', 'score': 0.5390204191207886}
# {'label': 'positive', 'score': 0.5816424489021301}
# {'label': 'negative', 'score': 0.9271389842033386}
# {'label': 'positive', 'score': 0.7489689588546753}
# {'label': 'negative', 'score': 0.5576635599136353}
# {'label': 'positive', 'score': 0.812820553779602}
# {'label': 'negative', 'score': 0.9752867221832275}
# {'label': 'negative', 'score': 0.9623468518257141}
# {'label': 'negative', 'score': 0.9717602729797363}
# {'label': 'negative', 'score': 0.9742559790611267}
# {'label': 'negative', 'score': 0.9764386415481567}
# {'label': 'negative', 'score': 0.9733685851097107}
# {'label': 'negative', 'score': 0.9391232132911682}
# {'label': 'negative', 'score': 0.9750704169273376}
# {'label': 'negative', 'score': 0.9762907028198242}
# {'label': 'negative', 'score': 0.9741415977478027}
# {'label': 'negative', 'score': 0.9749993681907654}
# {'label': 'negative', 'score': 0.97622150182724}
# {'label': 'negative', 'score': 0.9763047695159912}
# {'label': 'negative', 'score': 0.9755958318710327}
# {'label': 'negative', 'score': 0.975615918636322}
# {'label': 'negative', 'score': 0.9764232039451599}
# {'label': 'neutral', 'score': 0.7615713477134705}
# {'label': 'positive', 'score': 0.9525552988052368}
# {'label': 'positive', 'score': 0.9030566811561584}
# {'label': 'positive', 'score': 0.9431911110877991}
# {'label': 'positive', 'score': 0.9520341157913208}
# {'label': 'positive', 'score': 0.9519317150115967}
# {'label': 'positive', 'score': 0.9471466541290283}
# {'label': 'positive', 'score': 0.9569025635719299}
# {'label': 'negative', 'score': 0.8868576288223267}
# {'label': 'neutral', 'score': 0.7246779203414917}
# {'label': 'neutral', 'score': 0.786565363407135}
# {'label': 'positive', 'score': 0.9377530217170715}
# {'label': 'positive', 'score': 0.9343903660774231}
# {'label': 'positive', 'score': 0.9336784482002258}
# {'label': 'negative', 'score': 0.9690508246421814}
# {'label': 'negative', 'score': 0.9691150188446045}
# {'label': 'positive', 'score': 0.9553701877593994}
# {'label': 'positive', 'score': 0.9504378437995911}
# {'label': 'positive', 'score': 0.9538950324058533}
# {'label': 'positive', 'score': 0.9161967635154724}
# {'label': 'positive', 'score': 0.9598405361175537}
# {'label': 'positive', 'score': 0.9543221592903137}
# {'label': 'positive', 'score': 0.6865115165710449}
# {'label': 'neutral', 'score': 0.8810662627220154}
# {'label': 'positive', 'score': 0.9229490160942078}
# {'label': 'positive', 'score': 0.8316164016723633}
# {'label': 'positive', 'score': 0.9494754672050476}
# {'label': 'negative', 'score': 0.9756292700767517}
# {'label': 'positive', 'score': 0.5833203196525574}
# {'label': 'positive', 'score': 0.9451589584350586}
# {'label': 'positive', 'score': 0.9564365744590759}
# {'label': 'positive', 'score': 0.9575240612030029}
# {'label': 'positive', 'score': 0.9556930065155029}
# {'label': 'positive', 'score': 0.9554136991500854}
# {'label': 'positive', 'score': 0.9578128457069397}
# {'label': 'positive', 'score': 0.9498171210289001}
# {'label': 'positive', 'score': 0.957705557346344}
# {'label': 'positive', 'score': 0.9556992650032043}
# {'label': 'positive', 'score': 0.9567199945449829}
# {'label': 'positive', 'score': 0.9309329390525818}
# {'label': 'positive', 'score': 0.7267982363700867}
# {'label': 'neutral', 'score': 0.9541414976119995}
# {'label': 'positive', 'score': 0.821309506893158}
# {'label': 'positive', 'score': 0.9536918997764587}
# {'label': 'positive', 'score': 0.9576824903488159}
# {'label': 'positive', 'score': 0.545067548751831}
# {'label': 'negative', 'score': 0.9710943102836609}
# {'label': 'negative', 'score': 0.9605090022087097}
# {'label': 'negative', 'score': 0.9556336998939514}
# {'label': 'negative', 'score': 0.9132066965103149}
# {'label': 'negative', 'score': 0.9569249749183655}
# {'label': 'negative', 'score': 0.9312775135040283}
# {'label': 'positive', 'score': 0.7429234981536865}
# {'label': 'positive', 'score': 0.9216468930244446}
# {'label': 'positive', 'score': 0.9418473839759827}
# {'label': 'positive', 'score': 0.9502188563346863}
# {'label': 'positive', 'score': 0.8457896113395691}
# {'label': 'positive', 'score': 0.9491704702377319}
# {'label': 'positive', 'score': 0.914741039276123}
# {'label': 'positive', 'score': 0.7617399096488953}
# {'label': 'positive', 'score': 0.9543605446815491}
# {'label': 'positive', 'score': 0.8743473887443542}
# {'label': 'positive', 'score': 0.9504320025444031}
# {'label': 'positive', 'score': 0.9436063170433044}
# {'label': 'neutral', 'score': 0.8897731900215149}
# {'label': 'positive', 'score': 0.9073299169540405}
# {'label': 'positive', 'score': 0.9515342712402344}
# {'label': 'positive', 'score': 0.9561248421669006}
# {'label': 'positive', 'score': 0.947274923324585}
# {'label': 'positive', 'score': 0.9399049282073975}
# {'label': 'positive', 'score': 0.9501467347145081}
# {'label': 'neutral', 'score': 0.5761635303497314}
# {'label': 'positive', 'score': 0.8787739872932434}
# {'label': 'positive', 'score': 0.9435439705848694}
# {'label': 'positive', 'score': 0.9489585161209106}
# {'label': 'neutral', 'score': 0.8153257966041565}
# {'label': 'positive', 'score': 0.9418306946754456}
# {'label': 'positive', 'score': 0.9434810280799866}
# {'label': 'positive', 'score': 0.9337965250015259}
# {'label': 'positive', 'score': 0.926291286945343}
# {'label': 'positive', 'score': 0.49716898798942566}
# {'label': 'positive', 'score': 0.8360868096351624}
# {'label': 'positive', 'score': 0.9488916397094727}
# {'label': 'positive', 'score': 0.9532084465026855}
# {'label': 'positive', 'score': 0.9506736397743225}
# {'label': 'positive', 'score': 0.9536544680595398}
# {'label': 'positive', 'score': 0.9438847899436951}
# {'label': 'positive', 'score': 0.6535128355026245}
# {'label': 'positive', 'score': 0.9498370885848999}
# {'label': 'positive', 'score': 0.9541494250297546}
# {'label': 'positive', 'score': 0.9475617408752441}
# {'label': 'positive', 'score': 0.952532172203064}
# {'label': 'positive', 'score': 0.9566646814346313}
# {'label': 'positive', 'score': 0.9560331702232361}
# {'label': 'positive', 'score': 0.6318040490150452}
# {'label': 'neutral', 'score': 0.9218375086784363}
# {'label': 'positive', 'score': 0.9457499384880066}
# {'label': 'positive', 'score': 0.93873530626297}
# {'label': 'positive', 'score': 0.9422510862350464}
# {'label': 'positive', 'score': 0.955659031867981}
# {'label': 'positive', 'score': 0.9151063561439514}
# {'label': 'positive', 'score': 0.6349233388900757}
# {'label': 'positive', 'score': 0.7807393074035645}
# {'label': 'neutral', 'score': 0.6446130871772766}
# {'label': 'neutral', 'score': 0.6446130871772766}
# {'label': 'positive', 'score': 0.906174898147583}
# {'label': 'positive', 'score': 0.9339288473129272}
# {'label': 'positive', 'score': 0.9434471130371094}
# {'label': 'positive', 'score': 0.9312379360198975}
# {'label': 'positive', 'score': 0.9014961123466492}
# {'label': 'positive', 'score': 0.7650910019874573}
# {'label': 'positive', 'score': 0.9166689515113831}
# {'label': 'positive', 'score': 0.8807771801948547}
# {'label': 'positive', 'score': 0.9555890560150146}
# {'label': 'positive', 'score': 0.9236117005348206}
# {'label': 'positive', 'score': 0.7119225263595581}
# {'label': 'positive', 'score': 0.9484144449234009}
# {'label': 'neutral', 'score': 0.8017072677612305}
# {'label': 'positive', 'score': 0.9410394430160522}
# {'label': 'positive', 'score': 0.9380391240119934}
# {'label': 'positive', 'score': 0.8037347793579102}
# {'label': 'positive', 'score': 0.9240407347679138}
# {'label': 'positive', 'score': 0.9436006546020508}
# {'label': 'positive', 'score': 0.9366104006767273}
# {'label': 'positive', 'score': 0.9500421285629272}
# {'label': 'positive', 'score': 0.9449496269226074}
# {'label': 'positive', 'score': 0.9308138489723206}
# {'label': 'positive', 'score': 0.93756103515625}
# {'label': 'positive', 'score': 0.9615761041641235}
# {'label': 'positive', 'score': 0.9523111581802368}
# {'label': 'positive', 'score': 0.666466236114502}
# {'label': 'positive', 'score': 0.9558863043785095}
# {'label': 'positive', 'score': 0.9307769536972046}
# {'label': 'positive', 'score': 0.8961259126663208}
# {'label': 'positive', 'score': 0.801655113697052}
# {'label': 'positive', 'score': 0.8410719037055969}
# {'label': 'positive', 'score': 0.9478480815887451}
# {'label': 'neutral', 'score': 0.5278410911560059}
# {'label': 'positive', 'score': 0.9581531882286072}
# {'label': 'positive', 'score': 0.8675944805145264}
# {'label': 'neutral', 'score': 0.8808685541152954}
# {'label': 'positive', 'score': 0.9472182989120483}
# {'label': 'positive', 'score': 0.9451121091842651}
# {'label': 'positive', 'score': 0.9503962397575378}
# {'label': 'positive', 'score': 0.9385448694229126}
# {'label': 'positive', 'score': 0.9000468850135803}
# {'label': 'positive', 'score': 0.9611947536468506}
# {'label': 'positive', 'score': 0.941978394985199}
# {'label': 'positive', 'score': 0.9497625827789307}
# {'label': 'positive', 'score': 0.9511358141899109}
# {'label': 'positive', 'score': 0.9400418400764465}
# {'label': 'positive', 'score': 0.7820573449134827}
# {'label': 'positive', 'score': 0.9460781216621399}
# {'label': 'positive', 'score': 0.9379358887672424}
# {'label': 'positive', 'score': 0.9457278847694397}
# {'label': 'neutral', 'score': 0.6002535820007324}
# {'label': 'positive', 'score': 0.8855240345001221}
# {'label': 'positive', 'score': 0.9110782146453857}
# {'label': 'positive', 'score': 0.9504427909851074}
# {'label': 'positive', 'score': 0.8210115432739258}
# {'label': 'positive', 'score': 0.7113675475120544}
# {'label': 'neutral', 'score': 0.878112256526947}
# {'label': 'positive', 'score': 0.8628937602043152}
# {'label': 'positive', 'score': 0.885079562664032}
# {'label': 'negative', 'score': 0.8420304656028748}
# {'label': 'positive', 'score': 0.9455087780952454}
# {'label': 'positive', 'score': 0.9359870553016663}
# {'label': 'neutral', 'score': 0.8982008695602417}
# {'label': 'positive', 'score': 0.7479058504104614}
# {'label': 'neutral', 'score': 0.7704799771308899}
# {'label': 'neutral', 'score': 0.7403756380081177}
# {'label': 'positive', 'score': 0.8425807356834412}
# {'label': 'neutral', 'score': 0.7864035367965698}
# {'label': 'positive', 'score': 0.8512527346611023}
# {'label': 'positive', 'score': 0.8505071997642517}
# {'label': 'positive', 'score': 0.9498793482780457}
# {'label': 'positive', 'score': 0.9442790746688843}
# {'label': 'positive', 'score': 0.944758415222168}
# {'label': 'positive', 'score': 0.9520587921142578}
# {'label': 'positive', 'score': 0.8841400742530823}
# {'label': 'neutral', 'score': 0.8641849756240845}
# {'label': 'positive', 'score': 0.7336756587028503}
# {'label': 'positive', 'score': 0.9458706378936768}
# {'label': 'positive', 'score': 0.7333581447601318}
# {'label': 'neutral', 'score': 0.7869690656661987}
# {'label': 'positive', 'score': 0.9395360350608826}
# {'label': 'positive', 'score': 0.9303196668624878}
# {'label': 'positive', 'score': 0.9489137530326843}
# {'label': 'positive', 'score': 0.7911478877067566}
# {'label': 'positive', 'score': 0.8718858361244202}
# {'label': 'positive', 'score': 0.9498106241226196}
# {'label': 'positive', 'score': 0.5747024416923523}
# {'label': 'positive', 'score': 0.9152060151100159}
# {'label': 'positive', 'score': 0.9582210183143616}
# {'label': 'positive', 'score': 0.9552876353263855}
# {'label': 'positive', 'score': 0.9491856694221497}
# {'label': 'positive', 'score': 0.9273674488067627}
# {'label': 'neutral', 'score': 0.7992965579032898}
# {'label': 'positive', 'score': 0.952409029006958}
# {'label': 'positive', 'score': 0.954476535320282}
# {'label': 'positive', 'score': 0.8690521717071533}
# {'label': 'positive', 'score': 0.876143217086792}
# {'label': 'positive', 'score': 0.738161027431488}
# {'label': 'positive', 'score': 0.9411472082138062}
# {'label': 'positive', 'score': 0.9496082067489624}
# {'label': 'positive', 'score': 0.940022885799408}
# {'label': 'positive', 'score': 0.5542070865631104}
# {'label': 'positive', 'score': 0.9452290534973145}
# {'label': 'positive', 'score': 0.6578860282897949}
# {'label': 'positive', 'score': 0.9475700259208679}
# {'label': 'positive', 'score': 0.9384664297103882}
# {'label': 'positive', 'score': 0.9517281651496887}
# {'label': 'positive', 'score': 0.8933433890342712}
# {'label': 'neutral', 'score': 0.811506450176239}
# {'label': 'positive', 'score': 0.7241749167442322}
# {'label': 'positive', 'score': 0.9320597052574158}
# {'label': 'positive', 'score': 0.9451718330383301}
# {'label': 'negative', 'score': 0.6810452938079834}
# {'label': 'positive', 'score': 0.8126966953277588}
# {'label': 'positive', 'score': 0.948260486125946}
# {'label': 'positive', 'score': 0.8282897472381592}
# {'label': 'positive', 'score': 0.9510120153427124}
# {'label': 'positive', 'score': 0.8656575083732605}
# {'label': 'positive', 'score': 0.9452655911445618}
# {'label': 'positive', 'score': 0.8567283749580383}
# {'label': 'positive', 'score': 0.8497454524040222}
# {'label': 'neutral', 'score': 0.6242278218269348}
# {'label': 'positive', 'score': 0.8494797348976135}
# {'label': 'positive', 'score': 0.6657162308692932}
# {'label': 'positive', 'score': 0.9570391774177551}
# {'label': 'positive', 'score': 0.8046555519104004}
# {'label': 'neutral', 'score': 0.5125125646591187}
# {'label': 'positive', 'score': 0.8656061291694641}
# {'label': 'positive', 'score': 0.8973520994186401}
# {'label': 'positive', 'score': 0.606481671333313}
# {'label': 'positive', 'score': 0.8278611898422241}
# {'label': 'positive', 'score': 0.7849977016448975}
# {'label': 'positive', 'score': 0.9490261077880859}
# {'label': 'positive', 'score': 0.9242874979972839}
# {'label': 'positive', 'score': 0.9426998496055603}
# {'label': 'positive', 'score': 0.9051766395568848}
# {'label': 'negative', 'score': 0.5802528858184814}
# {'label': 'positive', 'score': 0.951406717300415}
# {'label': 'positive', 'score': 0.8964065313339233}
# {'label': 'positive', 'score': 0.9185366034507751}
# {'label': 'positive', 'score': 0.9280804395675659}
# {'label': 'positive', 'score': 0.8703750967979431}
# {'label': 'positive', 'score': 0.9408981800079346}
# {'label': 'positive', 'score': 0.9471642971038818}
# {'label': 'positive', 'score': 0.952104389667511}
# {'label': 'positive', 'score': 0.9270997643470764}
# {'label': 'positive', 'score': 0.9488463997840881}
# {'label': 'positive', 'score': 0.9520084261894226}
# {'label': 'positive', 'score': 0.9455678462982178}
# {'label': 'positive', 'score': 0.9482633471488953}
# ...
# {'label': 'negative', 'score': 0.9690293669700623}
# {'label': 'negative', 'score': 0.941524863243103}
# {'label': 'negative', 'score': 0.9691660404205322}
# {'label': 'neutral', 'score': 0.7854079604148865}
# {'label': 'negative', 'score': 0.9620760083198547}
# {'label': 'positive', 'score': 0.7859941720962524}
# {'label': 'neutral', 'score': 0.9043689370155334}
# {'label': 'negative', 'score': 0.9717369675636292}
# {'label': 'neutral', 'score': 0.7609781622886658}
# {'label': 'negative', 'score': 0.9153182506561279}
# {'label': 'negative', 'score': 0.5010334849357605}
# {'label': 'neutral', 'score': 0.9154097437858582}
# {'label': 'negative', 'score': 0.6754869818687439}
# {'label': 'neutral', 'score': 0.840994656085968}
# {'label': 'negative', 'score': 0.9544806480407715}
# {'label': 'neutral', 'score': 0.5062448382377625}
# {'label': 'neutral', 'score': 0.9487292170524597}
# {'label': 'neutral', 'score': 0.8388563394546509}
# {'label': 'negative', 'score': 0.9682438373565674}
# {'label': 'neutral', 'score': 0.9096893072128296}
# {'label': 'negative', 'score': 0.9634895324707031}
# {'label': 'negative', 'score': 0.5482922196388245}
# {'label': 'negative', 'score': 0.9611817598342896}
# {'label': 'negative', 'score': 0.9735915660858154}
# {'label': 'negative', 'score': 0.9743914604187012}
# {'label': 'negative', 'score': 0.9712486863136292}
# {'label': 'negative', 'score': 0.9323036074638367}
# {'label': 'negative', 'score': 0.9566845297813416}
# {'label': 'negative', 'score': 0.9644400477409363}
# {'label': 'negative', 'score': 0.975635290145874}
# {'label': 'negative', 'score': 0.8919137716293335}
# {'label': 'negative', 'score': 0.9632348418235779}
# {'label': 'negative', 'score': 0.9630458354949951}
# {'label': 'negative', 'score': 0.9646592140197754}
# {'label': 'negative', 'score': 0.6780381798744202}
# {'label': 'negative', 'score': 0.9760549068450928}
# {'label': 'negative', 'score': 0.9148704409599304}
# {'label': 'positive', 'score': 0.881682813167572}
# {'label': 'positive', 'score': 0.9001991152763367}
# {'label': 'neutral', 'score': 0.8653244972229004}
# {'label': 'neutral', 'score': 0.7560485601425171}
# {'label': 'neutral', 'score': 0.7394670248031616}
# {'label': 'negative', 'score': 0.949039101600647}
# {'label': 'negative', 'score': 0.9669837355613708}
# {'label': 'positive', 'score': 0.9232190251350403}
# {'label': 'negative', 'score': 0.9723992347717285}
# {'label': 'negative', 'score': 0.9492669105529785}
# {'label': 'neutral', 'score': 0.6270211935043335}
# {'label': 'negative', 'score': 0.9743357300758362}
# {'label': 'negative', 'score': 0.9746716618537903}
# {'label': 'negative', 'score': 0.9746772050857544}
# {'label': 'negative', 'score': 0.9746508002281189}
# {'label': 'negative', 'score': 0.9737486243247986}
# {'label': 'negative', 'score': 0.9741350412368774}
# {'label': 'negative', 'score': 0.9745427966117859}
# {'label': 'negative', 'score': 0.9656254053115845}
# {'label': 'negative', 'score': 0.9747535586357117}
# {'label': 'negative', 'score': 0.9746208190917969}
# {'label': 'negative', 'score': 0.9746938347816467}
# {'label': 'negative', 'score': 0.9747691750526428}
# {'label': 'negative', 'score': 0.9734609723091125}
# {'label': 'negative', 'score': 0.49839547276496887}
# {'label': 'negative', 'score': 0.9767550826072693}
# {'label': 'negative', 'score': 0.976601243019104}
# {'label': 'negative', 'score': 0.9766814112663269}
# {'label': 'negative', 'score': 0.9768133163452148}
# {'label': 'negative', 'score': 0.9766526222229004}
# {'label': 'negative', 'score': 0.9764291048049927}
# {'label': 'negative', 'score': 0.7873333096504211}
# {'label': 'negative', 'score': 0.9732334017753601}
# {'label': 'neutral', 'score': 0.5351030230522156}
# {'label': 'positive', 'score': 0.8655515313148499}
# {'label': 'neutral', 'score': 0.9246992468833923}
# {'label': 'neutral', 'score': 0.9404147863388062}
# {'label': 'negative', 'score': 0.9228023290634155}
# {'label': 'negative', 'score': 0.9463236331939697}
# {'label': 'negative', 'score': 0.88517826795578}
# {'label': 'neutral', 'score': 0.8690299391746521}
# {'label': 'negative', 'score': 0.9686756134033203}
# {'label': 'negative', 'score': 0.9707769751548767}
# {'label': 'negative', 'score': 0.9223862886428833}
# {'label': 'neutral', 'score': 0.7457338571548462}
# {'label': 'negative', 'score': 0.9752806425094604}
# {'label': 'negative', 'score': 0.9745582938194275}
# {'label': 'neutral', 'score': 0.6505218148231506}
# {'label': 'negative', 'score': 0.9726496338844299}
# {'label': 'negative', 'score': 0.9715253114700317}
# {'label': 'neutral', 'score': 0.9328405857086182}
# {'label': 'negative', 'score': 0.9755377173423767}
# {'label': 'negative', 'score': 0.9654042720794678}
# {'label': 'negative', 'score': 0.966786801815033}
# {'label': 'negative', 'score': 0.9391811490058899}
# {'label': 'negative', 'score': 0.9663863182067871}
# {'label': 'negative', 'score': 0.970618486404419}
# {'label': 'neutral', 'score': 0.7702205777168274}
# {'label': 'negative', 'score': 0.9724704623222351}
# {'label': 'neutral', 'score': 0.7985837459564209}
# {'label': 'negative', 'score': 0.9634754657745361}
# {'label': 'negative', 'score': 0.972156822681427}
# {'label': 'negative', 'score': 0.9701291918754578}
# {'label': 'negative', 'score': 0.9666500091552734}
# {'label': 'negative', 'score': 0.9736610651016235}
# {'label': 'negative', 'score': 0.9657338857650757}
# {'label': 'negative', 'score': 0.9731020927429199}
# {'label': 'negative', 'score': 0.9766262173652649}
# {'label': 'negative', 'score': 0.9711790680885315}
# {'label': 'negative', 'score': 0.9752654433250427}
# {'label': 'negative', 'score': 0.9712945818901062}
# {'label': 'negative', 'score': 0.9670170545578003}
# {'label': 'negative', 'score': 0.9742262363433838}
# {'label': 'negative', 'score': 0.9748712182044983}
# {'label': 'negative', 'score': 0.9726669788360596}
# {'label': 'negative', 'score': 0.9766149520874023}
# {'label': 'negative', 'score': 0.9769784808158875}
# {'label': 'negative', 'score': 0.9742864370346069}
# {'label': 'negative', 'score': 0.9743121266365051}
# {'label': 'negative', 'score': 0.9759975075721741}
# {'label': 'negative', 'score': 0.9762623906135559}
# {'label': 'negative', 'score': 0.9762727618217468}
# {'label': 'negative', 'score': 0.9760235548019409}
# {'label': 'negative', 'score': 0.9758137464523315}
# {'label': 'negative', 'score': 0.9756988286972046}
# {'label': 'negative', 'score': 0.971401572227478}
# {'label': 'negative', 'score': 0.9740028381347656}
# {'label': 'negative', 'score': 0.9755344390869141}
# {'label': 'negative', 'score': 0.9759048819541931}
# {'label': 'negative', 'score': 0.9757830500602722}
# {'label': 'negative', 'score': 0.9756126999855042}
# {'label': 'negative', 'score': 0.8924321532249451}
# {'label': 'negative', 'score': 0.9759185910224915}
# {'label': 'negative', 'score': 0.976452648639679}
# {'label': 'negative', 'score': 0.9758937358856201}
# {'label': 'negative', 'score': 0.9744190573692322}
# {'label': 'negative', 'score': 0.9758682250976562}
# {'label': 'negative', 'score': 0.9762881994247437}
# {'label': 'negative', 'score': 0.9760973453521729}
# {'label': 'negative', 'score': 0.9748527407646179}
# {'label': 'negative', 'score': 0.9705179929733276}
# {'label': 'negative', 'score': 0.9750089049339294}
# {'label': 'negative', 'score': 0.9760183095932007}
# {'label': 'negative', 'score': 0.9750217199325562}
# {'label': 'negative', 'score': 0.9755257368087769}
# {'label': 'negative', 'score': 0.9762943387031555}
# {'label': 'negative', 'score': 0.9756550788879395}
# {'label': 'positive', 'score': 0.7567685842514038}
# {'label': 'negative', 'score': 0.976345956325531}
# {'label': 'negative', 'score': 0.97510826587677}
# {'label': 'negative', 'score': 0.9755157232284546}
# {'label': 'negative', 'score': 0.9755643010139465}
# {'label': 'negative', 'score': 0.974614143371582}
# {'label': 'negative', 'score': 0.9740656018257141}
# {'label': 'negative', 'score': 0.9757063388824463}
# {'label': 'negative', 'score': 0.9752639532089233}
# {'label': 'negative', 'score': 0.974524199962616}
# {'label': 'negative', 'score': 0.9746427536010742}
# {'label': 'negative', 'score': 0.9752647280693054}
# {'label': 'negative', 'score': 0.9757040739059448}
# {'label': 'negative', 'score': 0.9755640625953674}
# {'label': 'negative', 'score': 0.9762150645256042}
# {'label': 'negative', 'score': 0.9743717312812805}
# {'label': 'negative', 'score': 0.9766111373901367}
# {'label': 'negative', 'score': 0.9761320948600769}
# {'label': 'negative', 'score': 0.975369393825531}
# {'label': 'negative', 'score': 0.9750221371650696}
# {'label': 'negative', 'score': 0.9764088988304138}
# {'label': 'negative', 'score': 0.976175844669342}
# {'label': 'negative', 'score': 0.9751431941986084}
# {'label': 'negative', 'score': 0.9759230613708496}
# {'label': 'negative', 'score': 0.9759984612464905}
# {'label': 'negative', 'score': 0.9765623211860657}
# {'label': 'negative', 'score': 0.9760815501213074}
# {'label': 'negative', 'score': 0.9765215516090393}
# {'label': 'negative', 'score': 0.9764911532402039}
# {'label': 'negative', 'score': 0.9756894111633301}
# {'label': 'negative', 'score': 0.9749769568443298}
# {'label': 'negative', 'score': 0.9760974645614624}
# {'label': 'negative', 'score': 0.9767041206359863}
# {'label': 'negative', 'score': 0.9693298935890198}
# {'label': 'negative', 'score': 0.9766150712966919}
# {'label': 'negative', 'score': 0.9762541055679321}
# {'label': 'negative', 'score': 0.9766974449157715}
# {'label': 'negative', 'score': 0.9773287177085876}
# {'label': 'negative', 'score': 0.9710935354232788}
# {'label': 'negative', 'score': 0.9762749075889587}
# {'label': 'negative', 'score': 0.9613590836524963}
# {'label': 'negative', 'score': 0.9721561670303345}
# {'label': 'negative', 'score': 0.9712382555007935}
# {'label': 'negative', 'score': 0.9758283495903015}
# {'label': 'negative', 'score': 0.9739954471588135}
# {'label': 'negative', 'score': 0.9724981784820557}
# {'label': 'negative', 'score': 0.9756363034248352}
# {'label': 'negative', 'score': 0.9732292294502258}
# {'label': 'negative', 'score': 0.9756942987442017}
# {'label': 'negative', 'score': 0.976184606552124}
# {'label': 'negative', 'score': 0.9760698676109314}
# {'label': 'negative', 'score': 0.9759981036186218}
# {'label': 'negative', 'score': 0.975927472114563}
# {'label': 'negative', 'score': 0.9731909036636353}
# {'label': 'negative', 'score': 0.9698953032493591}
# {'label': 'negative', 'score': 0.9695081114768982}
# {'label': 'negative', 'score': 0.9758466482162476}
# {'label': 'negative', 'score': 0.9719744324684143}
# {'label': 'negative', 'score': 0.9750257730484009}
# {'label': 'negative', 'score': 0.9738117456436157}
# {'label': 'negative', 'score': 0.974240243434906}
# {'label': 'negative', 'score': 0.9749944806098938}
# {'label': 'negative', 'score': 0.9719226360321045}
# {'label': 'negative', 'score': 0.9761853814125061}
# {'label': 'negative', 'score': 0.9751690626144409}
# {'label': 'negative', 'score': 0.9724393486976624}
# {'label': 'negative', 'score': 0.9757271409034729}
# {'label': 'negative', 'score': 0.9700709581375122}
# {'label': 'negative', 'score': 0.9755879044532776}
# {'label': 'negative', 'score': 0.9755206108093262}
# {'label': 'negative', 'score': 0.9633234143257141}
# {'label': 'negative', 'score': 0.9762543439865112}
# {'label': 'negative', 'score': 0.9749720692634583}
# {'label': 'negative', 'score': 0.9746065139770508}
# {'label': 'negative', 'score': 0.9765557646751404}
# {'label': 'negative', 'score': 0.9765561819076538}
# {'label': 'negative', 'score': 0.9768009185791016}
# {'label': 'negative', 'score': 0.9770232439041138}
# {'label': 'negative', 'score': 0.9769352674484253}
# {'label': 'negative', 'score': 0.9768462777137756}
# {'label': 'negative', 'score': 0.976323664188385}
# {'label': 'negative', 'score': 0.9768427610397339}
# {'label': 'negative', 'score': 0.9765220880508423}
# {'label': 'negative', 'score': 0.976264476776123}
# {'label': 'negative', 'score': 0.9767122864723206}
# {'label': 'negative', 'score': 0.9748945832252502}
# {'label': 'negative', 'score': 0.9750637412071228}
# {'label': 'negative', 'score': 0.9727591276168823}
# {'label': 'negative', 'score': 0.9606978297233582}
# {'label': 'negative', 'score': 0.9712603688240051}
# {'label': 'negative', 'score': 0.9758013486862183}
# {'label': 'negative', 'score': 0.9752587080001831}
# {'label': 'negative', 'score': 0.9734932780265808}
# {'label': 'negative', 'score': 0.9757064580917358}
# {'label': 'negative', 'score': 0.9129921197891235}
# {'label': 'negative', 'score': 0.9737822413444519}
# {'label': 'negative', 'score': 0.9749377369880676}
# {'label': 'negative', 'score': 0.9763398766517639}
# {'label': 'positive', 'score': 0.9559077620506287}
# {'label': 'positive', 'score': 0.9103409647941589}
# {'label': 'positive', 'score': 0.6872799396514893}
# {'label': 'neutral', 'score': 0.9487746357917786}
# {'label': 'positive', 'score': 0.8345257639884949}
# {'label': 'neutral', 'score': 0.6895818114280701}
# {'label': 'positive', 'score': 0.8728678226470947}
# {'label': 'positive', 'score': 0.8792709708213806}
# {'label': 'negative', 'score': 0.9605286717414856}
# {'label': 'negative', 'score': 0.967720091342926}
# {'label': 'negative', 'score': 0.9623751044273376}
# {'label': 'negative', 'score': 0.9758251905441284}
# {'label': 'negative', 'score': 0.9731728434562683}
# {'label': 'positive', 'score': 0.951783299446106}
# {'label': 'neutral', 'score': 0.5756204128265381}
# {'label': 'negative', 'score': 0.9570590257644653}
# {'label': 'negative', 'score': 0.9662134051322937}
# {'label': 'negative', 'score': 0.9750916361808777}
# {'label': 'negative', 'score': 0.9762114882469177}
# {'label': 'negative', 'score': 0.9752172231674194}
# {'label': 'negative', 'score': 0.9655092358589172}
# {'label': 'neutral', 'score': 0.9287604689598083}
# {'label': 'negative', 'score': 0.9726866483688354}
# {'label': 'negative', 'score': 0.9739890098571777}
# {'label': 'negative', 'score': 0.9752402305603027}
# {'label': 'negative', 'score': 0.9747570157051086}
# {'label': 'negative', 'score': 0.9509196281433105}
# {'label': 'negative', 'score': 0.9728633761405945}
# {'label': 'negative', 'score': 0.975330650806427}
# {'label': 'negative', 'score': 0.8723368048667908}
# {'label': 'negative', 'score': 0.9763818383216858}
# {'label': 'positive', 'score': 0.8704223036766052}
# {'label': 'negative', 'score': 0.5738078951835632}
# {'label': 'neutral', 'score': 0.7948707342147827}
# {'label': 'neutral', 'score': 0.9402328729629517}
# {'label': 'negative', 'score': 0.92583829164505}
# {'label': 'neutral', 'score': 0.9234479665756226}
# {'label': 'neutral', 'score': 0.7383177280426025}
# {'label': 'neutral', 'score': 0.5421369671821594}
# {'label': 'positive', 'score': 0.873447835445404}
# {'label': 'negative', 'score': 0.9656736254692078}
# {'label': 'negative', 'score': 0.9681777954101562}
# {'label': 'negative', 'score': 0.9760786294937134}
# {'label': 'negative', 'score': 0.9753177165985107}
# {'label': 'negative', 'score': 0.9701237678527832}
# {'label': 'negative', 'score': 0.9148279428482056}
# {'label': 'neutral', 'score': 0.6861920952796936}
# {'label': 'neutral', 'score': 0.9149435758590698}
# {'label': 'negative', 'score': 0.9765880107879639}
# {'label': 'neutral', 'score': 0.8650155663490295}
# {'label': 'neutral', 'score': 0.6283149123191833}
# {'label': 'negative', 'score': 0.9504798054695129}
# {'label': 'negative', 'score': 0.9296106696128845}
# {'label': 'neutral', 'score': 0.8040826320648193}
# {'label': 'negative', 'score': 0.9758958220481873}
# {'label': 'negative', 'score': 0.9740539193153381}
# {'label': 'negative', 'score': 0.9673627614974976}
# {'label': 'negative', 'score': 0.9736167788505554}
# {'label': 'negative', 'score': 0.9606773853302002}
# {'label': 'negative', 'score': 0.9767640829086304}
# {'label': 'negative', 'score': 0.9737187027931213}
# {'label': 'negative', 'score': 0.9682580232620239}
# {'label': 'negative', 'score': 0.9758936166763306}
# {'label': 'negative', 'score': 0.9765318632125854}
# {'label': 'negative', 'score': 0.9731278419494629}
# {'label': 'negative', 'score': 0.9700900316238403}
# {'label': 'negative', 'score': 0.9745477437973022}
# {'label': 'negative', 'score': 0.9755401015281677}
# {'label': 'negative', 'score': 0.9700016379356384}
# {'label': 'negative', 'score': 0.9743436574935913}
# {'label': 'negative', 'score': 0.9767235517501831}
# {'label': 'negative', 'score': 0.9743572473526001}
# {'label': 'negative', 'score': 0.9744252562522888}

# %% [markdown]
# # Dianogsis

# %%
result_labels = []
for result in results:
    result_labels.append(result['label'])
    
print(result_labels)
# Out:
# ['neutral', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'neutral', 'negative', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive',  ...

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_true=data.iloc[:, 0], y_pred=result_labels)
# Out:
# 0.8893704850361197
